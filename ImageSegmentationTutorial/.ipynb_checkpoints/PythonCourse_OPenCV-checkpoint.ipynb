# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
# import liberaries
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


# read the image
img = cv2.imread("Image4045.tif",0)
print (img.shape, img.dtype, img.max(), img.min(), img.mean())

# display the image
imgplot = plt.imshow(img, cmap="gray")
# Out:
# (128, 128) uint8 173 1 82.91729736328125

# %%
# set the figure 
figure, axes = plt.subplots(nrows=2, ncols=2)
figure.tight_layout(pad=3.0) 

# resize the image
res = cv2.resize(img,None,fx=3, fy=3, interpolation = cv2.INTER_CUBIC) #scaling
rows,cols = res.shape
plt.subplot(221) 
imgplot = plt.imshow(res, cmap="gray")

# applly geometrical transformation
# make a shift of (100,50)
M = np.float32([[1,0,100],[0,1,50]])
dst = cv2.warpAffine(res,M,(cols,rows))
plt.subplot(222) 
imgplot = plt.imshow(dst, cmap="gray")

# rotate the image by 36 degree
M = cv2.getRotationMatrix2D((cols/2,rows/2),36,1)
dst = cv2.warpAffine(res,M,(cols,rows))
plt.subplot(223) 
imgplot = plt.imshow(dst, cmap="gray")

# rotate 270 degree 
M = cv2.getRotationMatrix2D((cols/2,rows/2),270,1)
dst = cv2.warpAffine(res,M,(cols,rows))
plt.subplot(224) 
imgplot = plt.imshow(dst, cmap="gray")

# write an image and save it
filename = 'savedImage.jpg'
cv2.imwrite(filename, dst)
# Out:
# True

# %%
# read the saved image
img = cv2.imread("savedImage.jpg",0)
print (img.shape, img.dtype)
imgplot = plt.imshow(img, cmap="gray")
# Out:
# (384, 384) uint8

# %%
img = cv2.imread("Image4045.tif",0)
rows,cols = img.shape
# Histogram
hist = cv2.calcHist([img],[0],None,[256],[0,256])

figure, axes = plt.subplots(nrows=1, ncols=2)
figure.tight_layout(pad=3.0) 
plt.subplot(121) 
imgplot = plt.imshow(img, cmap="gray")
plt.xticks([]), plt.yticks([])
plt.subplot(122) 
plt.hist(img.ravel(),256,[0,256]); plt.show()

# %%
# contrast and brightness enhancement
alpha = 1.5 # Contrast control (1.0-3.0)
beta = 0 # Brightness control (0-100)

cntr_adjusted = cv2.convertScaleAbs(img, alpha=1.8, beta=0)
brght_adjusted = cv2.convertScaleAbs(img, alpha= 1.8, beta=50)

figure, axes = plt.subplots(nrows=1, ncols=3)
figure.tight_layout(pad=4.0) 
plt.subplot(131) 
imgplot = plt.imshow(img, cmap="gray")
plt.title('originl image', fontSize = '10')
plt.xticks([]), plt.yticks([])
plt.subplot(132) 
imgplot = plt.imshow(cntr_adjusted, cmap="gray")
plt.title('contrast enhanced', fontSize = '10')
plt.xticks([]), plt.yticks([])
plt.subplot(133) 
imgplot = plt.imshow(brght_adjusted, cmap="gray")
plt.title('brightness enhanced', fontSize = '10')
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))

# %%
# smoothing image
kernel = np.ones((5,5),np.float32)/25
average_blur = cv2.filter2D(img,-1,kernel)
gaussian_blur = cv2.GaussianBlur(img,(5,5),0)
median_blur = cv2.medianBlur(img,5)

plt.subplot(221),plt.imshow(img,cmap="gray"),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(222),plt.imshow(average_blur,cmap="gray"),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.subplot(223),plt.imshow(gaussian_blur,cmap="gray"),plt.title('Gaussian smoothing')
plt.xticks([]), plt.yticks([])
plt.subplot(224),plt.imshow(median_blur,cmap="gray"),plt.title('Median smoothing')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
# gradient calculation 
img = cv2.imread('sudoku-original.jpg',0)

sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=11)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=11)
laplacian = cv2.Laplacian(img,cv2.CV_64F,ksize=11)

plt.subplot(141),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(142),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(143),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
plt.subplot(144),plt.imshow(laplacian,cmap = 'gray')
plt.title('laplacian'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
# gradient calculation 
img = cv2.imread('Image4045.tif',0)

sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=11)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=11)
laplacian = cv2.Laplacian(img,cv2.CV_64F,ksize=11)

plt.subplot(141),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(142),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(143),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
plt.subplot(144),plt.imshow(laplacian,cmap = 'gray')
plt.title('laplacian'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
# canny edge detection
edges = cv2.Canny(img,40,130)
kernel = np.ones((3,3),np.uint8)
dilation = cv2.dilate(edges,kernel,iterations = 1)
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(3,3))
opening = cv2.morphologyEx(dilation,cv2.MORPH_CLOSE,kernel,iterations = 1)
plt.subplot(131),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(opening,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
# thresholding
ret,thresh1 = cv2.threshold(img,90,255,cv2.THRESH_BINARY)
titles = ['Original Image','BINARY with thr = 90']
images = [img, thresh1]

for i in range(2):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()

# %%
# calculate metrics

#import the liberaries
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sn


def confusion_matrix(Target_array,Predicted_array):
  row,col = Target_array.shape
  tp,tn,fp,fn = [0,0,0,0]
  Cf_matrix = np.zeros((2,2))
  for i in range(row):
    for j in range(col):
      if Predicted_array[i,j] == Target_array[i,j] ==1:
        tp += 1
      if Predicted_array[i,j]==1 and Target_array[i,j]!=Predicted_array[i,j]:
        fp += 1
      if Target_array[i,j]==Predicted_array[i,j]==0:
        tn +=1
      if Predicted_array[i,j]==0 and Target_array[i,j]!=Predicted_array[i,j]:
        fn +=1
  Cf_matrix [0,0] = tn
  Cf_matrix [0,1] = fp
  Cf_matrix [1,0] = fn
  Cf_matrix [1,1] = tp
  return Cf_matrix 

# reda the images (input, target and predicted)
img = cv2.imread('Image4045.tif',0)
trgt = cv2.imread('Target.png',0)
prdct = cv2.imread('Predicted.png',0)
pair_mask = np.dstack((trgt, prdct,trgt))

titles = ['Original Image','Target Mask','Predicted Mask','Paired Masks']
images = [img, trgt, prdct, pair_mask]

for i in range(4):
    plt.subplot(1,4,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()

# calculate the confusion matrix and show 
trgt_array = np.array(trgt)/255
prdct_array = np.array(prdct)/255

Cf_matrix = confusion_matrix(trgt_array,prdct_array)
# print(Cf_matrix)

# display the matrix
df = pd.DataFrame(data=Cf_matrix, index=["0", "1"], columns=["0", "1"])
sn.heatmap(Cf_matrix, annot=True)
plt.xlabel('Predicted'), plt.ylabel('Target')
plt.show()


Normalized_cf_matrix = Cf_matrix / Cf_matrix.astype(np.float).sum(axis=1)
df = pd.DataFrame(data=Normalized_cf_matrix, index=["0", "1"], columns=["0", "1"])
sn.heatmap(Normalized_cf_matrix, annot=True)
plt.xlabel('Predicted'), plt.ylabel('Target')
plt.show()
# calculate the metrics 

tn = Cf_matrix [0,0] 
fp = Cf_matrix [0,1] 
fn = Cf_matrix [1,0] 
tp = Cf_matrix [1,1] 

Accuracy = (tp+tn)/(tp+tn+fp+fn)
Preciosion = tp/(tp+fp)
Dice_score = (2 * tp)/(2 * tp+fp+fn)

print('------ The evaluation metrics -----')
print ('Accuracy =', Accuracy)
print ('Preciosion = ',Preciosion)
print('Dice_score = ', Dice_score)
# Out:
# ------ The evaluation metrics -----
# Accuracy = 0.9715193223928005
# Preciosion =  0.9461217681401167
# Dice_score =  0.9547214273691298
